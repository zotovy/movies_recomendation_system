# %%
from datetime import datetime
import pandas as pd
import json
import iso639

# %% [markdown]
# # Data loading

# %%
tmdb_movies = pd.read_csv('../datasets/tmdb-dataset/tmdb_5000_movies.csv')
tmdb_credits = pd.read_csv('../datasets/tmdb-dataset/tmdb_5000_credits.csv')

# %%
tmdb_movies.head()
# Out:
#       budget                                             genres
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  \
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id
# 0                   http://www.avatarmovie.com/   19995  \
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en  \
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title
# 0                                    Avatar  \
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  \
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies
# 0  [{"name": "Ingenious Film Partners", "id": 289...  \
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087  \
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released  \
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline
# 0                     Enter the World of Pandora.  \
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
tmdb_credits.head()
# Out:
#    movie_id                                     title
# 0     19995                                    Avatar  \
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast
# 0  [{"cast_id": 242, "character": "Jake Sully", "...  \
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
# merge credits on movies
tmdb_credits = tmdb_credits.drop(columns=['title'])
tmdb_credits = tmdb_credits.rename(columns={ 'movie_id': 'id' })
tmdb_movies = pd.merge(tmdb_movies, tmdb_credits, on='id')

# %%
tmdb_movies.head()
# Out:
#       budget                                             genres
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  \
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id
# 0                   http://www.avatarmovie.com/   19995  \
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en  \
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title
# 0                                    Avatar  \
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  \
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...     revenue runtime
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  2787965087   162.0  \
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   961000000   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   880674609   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...  1084939099   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   284139100   132.0
#
#                                     spoken_languages    status
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released  \
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline
# 0                     Enter the World of Pandora.  \
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count
# 0                                    Avatar          7.2      11800  \
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast
# 0  [{"cast_id": 242, "character": "Jake Sully", "...  \
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 22 columns]

# %% [markdown]
# # Genres

# %%
def extract_genres(genres_str):
    genres_list = json.loads(genres_str)
    return [(genre['id'], genre['name']) for genre in genres_list]

# Applying the function to extract genres and flattening the list
genres_list = tmdb_movies.genres.apply(extract_genres).explode().tolist()

# Creating a DataFrame with unique genre IDs and names
genres_df = pd.DataFrame(genres_list, columns=['id', 'name']).drop_duplicates()

# Drop NA
genres_df = genres_df[genres_df['id'].notna()]

# Made id int
genres_df.id = genres_df.id.astype(int)

# %%
# Save it as .csv file
genres_df.to_csv('../datasets/own-dataset/genres.csv', index=False)

# %%
# replace tmdb_movies.genres with list of ids
def replace_genres(genres_str):
    genres_list = json.loads(genres_str)
    return [genre['id'] for genre in genres_list]

tmdb_movies.genres = tmdb_movies.genres.apply(replace_genres)

# %% [markdown]
# # Keywords

# %%
def extract_keywords(keywords_str):
    keywords_list = json.loads(keywords_str)
    return [(keyword['id'], keyword['name']) for keyword in keywords_list]

# Applying the function to extract keywords and flattening the list
keywords_list = tmdb_movies.keywords.apply(extract_keywords).explode().tolist()

# Creating a DataFrame with unique keywords IDs and names
keywords_df = pd.DataFrame(keywords_list, columns=['id', 'name']).drop_duplicates()

# Drop NA
keywords_df = keywords_df[keywords_df['id'].notna()]

# Made id int
keywords_df.id = keywords_df.id.astype(int)

# %%
# Save it as .csv file
keywords_df.to_csv('../datasets/own-dataset/keywords.csv', index=False)

# %%
# replace tmdb_movies.keywords with list of ids
def replace_keywords(keywords_str):
    keywords_list = json.loads(keywords_str)
    return [keyword['id'] for keyword in keywords_list]

tmdb_movies.keywords = tmdb_movies.keywords.apply(replace_keywords)

# %% [markdown]
# # Release date

# %%
tmdb_movies.release_date = pd.to_datetime(tmdb_movies.release_date)

# %%
def extract_production_companies(companies_str):
    companies_list = json.loads(companies_str)
    return [(company['id'], company['name']) for company in companies_list]

# Applying the function to extract production companies and flattening the list
companies_list = tmdb_movies.production_companies\
    .apply(extract_production_companies)\
    .explode()\
    .tolist()

# Creating a DataFrame with unique keywords IDs and names
companies_df = pd.DataFrame(companies_list, columns=['id', 'name']).drop_duplicates()

# Drop NA
companies_df = companies_df[companies_df['id'].notna()]

# Made id int
companies_df.id = companies_df.id.astype(int)

# %%
# Save it as .csv file
companies_df.to_csv('../datasets/own-dataset/production_companies.csv', index=False)

# %%
# replace tmdb_movies.production_companies with list of ids
def replace_production_companies(companies_str):
    companies_list = json.loads(companies_str)
    return [company['id'] for company in companies_list]

tmdb_movies.production_companies = tmdb_movies.production_companies.apply(replace_production_companies)

# %% [markdown]
# # Countries

# %%
def extract_production_countries(countries_str):
    countries_list = json.loads(countries_str)
    return [(country['iso_3166_1'], country['name']) for country in countries_list]

# Applying the function to extract production countries and flattening the list
countries_list = tmdb_movies.production_countries\
    .apply(extract_production_countries)\
    .explode()\
    .tolist()

# Creating a DataFrame with unique keywords IDs and names
countries_df = pd.DataFrame(countries_list, columns=['code', 'name']).drop_duplicates()

# Drop NA
countries_df = countries_df[countries_df['code'].notna() & countries_df['name'].notna()]

# %%
# Save it as .csv file
countries_df.to_csv('../datasets/own-dataset/countries.csv', index=False)

# %%
tmdb_movies.production_countries
# Out:
# 0       [{"iso_3166_1": "US", "name": "United States o...
# 1       [{"iso_3166_1": "US", "name": "United States o...
# 2       [{"iso_3166_1": "GB", "name": "United Kingdom"...
# 3       [{"iso_3166_1": "US", "name": "United States o...
# 4       [{"iso_3166_1": "US", "name": "United States o...
#                               ...
# 4798    [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...
# 4799                                                   []
# 4800    [{"iso_3166_1": "US", "name": "United States o...
# 4801    [{"iso_3166_1": "US", "name": "United States o...
# 4802    [{"iso_3166_1": "US", "name": "United States o...
# Name: production_countries, Length: 4803, dtype: object

# %%
# replace tmdb_movies.production_countries with list of ids
def replace_production_countries(countries_str):
    countries_list = json.loads(countries_str)
    return [country['iso_3166_1'] for country in countries_list]

tmdb_movies.production_countries = tmdb_movies.production_countries.apply(replace_production_countries)

# %%
tmdb_movies.production_countries
# Out:
# 0       [US, GB]
# 1           [US]
# 2       [GB, US]
# 3           [US]
# 4           [US]
#           ...
# 4798    [MX, US]
# 4799          []
# 4800        [US]
# 4801    [US, CN]
# 4802        [US]
# Name: production_countries, Length: 4803, dtype: object

# %% [markdown]
# # Spoken languages

# %%
def extract_spoken_languages(languages_str):
    languages_list = json.loads(languages_str)
    new_lang_list = []
    for language in languages_list:
        code = language['iso_639_1']
        if code == 'cn':
            new_lang_list.append((code, 'Chinese'))
        elif code == 'sh':
            new_lang_list.append((code, 'Serbo-Croatian'))
        elif code == 'xx':
            new_lang_list.append((code, 'Unknown'))
        else:
            new_lang_list.append((code, iso639.Language.from_part1(code).name))
    return new_lang_list

# Applying the function to extract spoken languages and flattening the list
languages_list = tmdb_movies.spoken_languages \
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Spanish
# Hindi
# English
# English
# English
# English
# English
# English
# Italian
# Portuguese
# English
# English
# English
# English
# French
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Indonesian
# English
# English
# English
# English
# Hindi
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Japanese
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Hindi
# English
# English
# English
# English
# English
# Hebrew
# English
# English
# English
# Indonesian
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Spanish
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Spanish
# German
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# German
# English
# English
# Romanian
# English
# English
# English
# Persian
# English
# English
# English
# English
# English
# French
# English
# English
# English
# English
# English
# English
# English
# Persian
# English
# English
# English
# English
# German
# English
# English
# English
# English
# English
# English
# Norwegian
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Italian
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# French
# English
# French
# English
# English
# English
# English
# Slovenian
# English
# Hindi
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Pushto
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Japanese
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Chinese
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Swedish
# English
# English
# English
# English
# English
# English
# Italian
# English
# English
# English
# English
# Italian
# Danish
# English
# English
# English
# English
# Swedish
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Modern Greek (1453-)
# English
# English
# English
# French
# English
# English
# English
# English
# English
# French
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Italian
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Italian
# English
# English
# English
# English
# German
# English
# English
# English
# English
# English
# English
# Portuguese
# English
# Danish
# English
# English
# English
# English
# English
# English
# English
# English
# Persian
# English
# English
# English
# Romanian
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# French
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# French
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Portuguese
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# English
# Persian
# English
# Japanese
# English
# English
# English
# English
# English
# Spanish
# English
# English
# English
# English

# %% [markdown]
# # Cast

# %%
def extract_cast(cast_str):
    cast_list = json.loads(cast_str)
    return [(cast['id'], cast['character'], cast['name'], cast['gender'], cast['order']) for cast in cast_list]

# Applying the function to extract cast and flattening the list
cast_list = tmdb_movies.cast.apply(extract_cast).explode().tolist()

# Creating a DataFrame with unique keywords IDs and names
cast_df = pd.DataFrame(cast_list, columns=['id', 'character', 'name', 'gender', 'order']).drop_duplicates()

# Drop NA
cast_df = cast_df[cast_df.id.notna()]

# Drop id duplicates
cast_df = cast_df.drop_duplicates(subset=['id'])

# Made id, gender and order int type
cast_df.id = cast_df.id.astype(int)
cast_df.gender = cast_df.gender.astype('Int64')
cast_df.order = cast_df.order.astype('Int64')

# Fill unknown characters
cast_df.character = cast_df.character.astype(str).apply(lambda x: x if len(x) > 0 else 'Unknown')

# %%
# Save it as .csv file
cast_df.to_csv('../datasets/own-dataset/cast.csv', index=False)

# %%
# replace tmdb_movies.cast with list of ids
def replace_cast(cast_str):
    cast_list = json.loads(cast_str)
    return [cast['id'] for cast in cast_list]

tmdb_movies.cast = tmdb_movies.cast.apply(replace_cast)

# %% [markdown]
# # Crew

# %%
def extract_crew(crew_str):
    crew_list = json.loads(crew_str)
    return [(crew['id'], crew['name'], crew['job'], crew['gender'], crew['department']) for crew in crew_list]

# Applying the function to extract crew and flattening the list
crew_list = tmdb_movies.crew.apply(extract_crew).explode().tolist()

# Creating a DataFrame with unique keywords IDs and names
crew_df = pd.DataFrame(crew_list, columns=['id', 'name', 'job', 'gender', 'department']).drop_duplicates()

# Drop NA
crew_df = crew_df[crew_df.id.notna()]

# Drop id duplicates
crew_df = crew_df.drop_duplicates(subset=['id'])

# Made id, gender int type
crew_df.id = crew_df.id.astype(int)
crew_df.gender = crew_df.gender.astype('Int64')

# %%
# Save it as .csv file
crew_df.to_csv('../datasets/own-dataset/crew.csv', index=False)

# %%
# replace tmdb_movies.crew with list of ids
def replace_crew(crew_str):
    crew_list = json.loads(crew_str)
    return [crew['id'] for crew in crew_list]

tmdb_movies.crew = tmdb_movies.crew.apply(replace_crew)

# %% [markdown]
# # Relations tables

# %%
movies_genres_df = pd.DataFrame(columns=['movie_id', 'genre_id'])
movies_keywords_df = pd.DataFrame(columns=['movie_id', 'keyword_id'])
movies_production_companies = pd.DataFrame(columns=['movie_id', 'production_company_id'])
movies_production_countries = pd.DataFrame(columns=['movie_id', 'country'])

for index in range(len(tmdb_movies)):
    movie = tmdb_movies.iloc[index]
    
    # Genre
    for genre in movie.genres:
        movies_genres_df.loc[len(movies_genres_df.index)] = {
            'movie_id': movie.id,
            'genre_id': genre,
        }
        
    # Keywords
    for keyword in movie.keywords:
        movies_keywords_df.loc[len(movies_keywords_df.index)] = {
            'movie_id': movie.id,
            'keyword_id': keyword,
        }

    # Production companies
    for company in movie.production_companies:
        movies_production_companies.loc[len(movies_production_companies.index)] = {
            'movie_id': movie.id,
            'production_company_id': company,
        }

    # Production countries
    for country in movie.production_countries:
        movies_production_countries.loc[len(movies_production_countries.index)] = {
            'movie_id': movie.id,
            'country': country,
        }

    # Production countries
    for language in movie.original_language:
        movies_original_languages.loc[len(movies_original_languages.index)] = {
            'movie_id': movie.id,
            'country_code': language,
        }
        

movies_genres_df.to_csv('../datasets/own-dataset/movies_genres.csv', index=False)
movies_keywords_df.to_csv('../datasets/own-dataset/movies_keywords.csv', index=False)
movies_production_companies.to_csv('../datasets/own-dataset/movies_production_companies.csv', index=False)
movies_production_countries.to_csv('../datasets/own-dataset/movies_production_countries.csv', index=False)

# %% [markdown]
# # Remove unused columns

# %%
# Replace NA 
tmdb_movies.overview = tmdb_movies.overview.fillna('')
tmdb_movies.release_date = tmdb_movies.release_date.fillna(datetime(2017, 1, 1))
tmdb_movies.runtime = tmdb_movies.runtime.fillna(0)

# Remove 
tmdb_movies = tmdb_movies.drop(columns=['genres', 'keywords', 'production_companies', 'production_countries', 'spoken_languages', 'cast', 'crew'])

# Reorder
tmdb_movies = tmdb_movies[['id', 'budget', 'homepage', 'original_language', 'original_title', 'overview', 'popularity', 'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count']]

# %%
tmdb_movies.to_csv('../datasets/own-dataset/movies.csv', index=False)

# %%
tmdb_movies.columns
# Out:
# Index(['id', 'budget', 'homepage', 'original_language', 'original_title',
#        'overview', 'popularity', 'release_date', 'revenue', 'runtime',
#        'status', 'tagline', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
crew_df
# Out:
#              id               name                      job  gender
# 0          1721  Stephen E. Rivkin                   Editor       0  \
# 1           496        Rick Carter        Production Design       2
# 2           900  Christopher Boyes           Sound Designer       0
# 4          1262          Mali Finn                  Casting       1
# 5          1729       James Horner  Original Music Composer       2
# ...         ...                ...                      ...     ...
# 129597  1012891         Renee Read        Production Design       1
# 129601  1271268       Lisa Binkley                   Editor       0
# 129602   208138        Daniel Hsia                 Director       2
# 129606    85563   Brian Herzlinger                 Director       2
# 129608   997560         Brett Winn                 Director       0
#
#         department
# 0          Editing
# 1              Art
# 2            Sound
# 4       Production
# 5            Sound
# ...            ...
# 129597         Art
# 129601     Editing
# 129602   Directing
# 129606   Directing
# 129608   Directing
#
# [52885 rows x 5 columns]

# %%
cast_df.isna().sum()
# Out:
# id           0
# character    0
# name         0
# gender       0
# order        0
# dtype: int64
